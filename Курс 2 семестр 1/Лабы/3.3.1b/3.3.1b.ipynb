# %%
import pandas as pd
import math as m
from IPython.display import display as disp
import lablib as ll
# %matplotlib inline

# %% [markdown]
# Загружаем данные. Также заметим, что деление шкалы амперметра в цепи питания соленоида — 0.03 A.

# %%
data, columns, experiments = ll.read_standard_layout()

I_f_unit = 0.004 # A per unit

for e in experiments:
    print("%s:" % e)
    disp(data[e], columns[e])
# Out:
# V_a=60:
#            Value    Error  ErrorRel
# _dB_dI  0.028000 0.000500  0.017857
# R_a     0.012000 0.000500  0.041667
# V_a    60.000000 0.500000  0.008333
#     I_f  Error_I_f  ErrorRel_I_f  I_a  Error_I_a  ErrorRel_I_a
# 0     0   0.500000           inf   96   0.500000      0.005208
# 1    10   0.500000      0.050000   90   0.500000      0.005556
# 2    20   0.500000      0.025000   90   0.500000      0.005556
# 3    25   0.500000      0.020000   83   0.500000      0.006024
# 4    29   0.500000      0.017241   71   0.500000      0.007042
# 5    31   0.500000      0.016129   70   0.500000      0.007143
# 6    32   0.500000      0.015625   65   0.500000      0.007692
# 7    33   0.500000      0.015152   62   0.500000      0.008065
# 8    34   0.500000      0.014706   61   0.500000      0.008197
# 9    35   0.500000      0.014286   59   0.500000      0.008475
# 10   36   0.500000      0.013889   55   0.500000      0.009091
# 11   37   0.500000      0.013514   51   0.500000      0.009804
# 12   38   0.500000      0.013158   44   0.500000      0.011364
# 13   39   0.500000      0.012821   38   0.500000      0.013158
# 14   40   0.500000      0.012500   28   0.500000      0.017857
# 15   41   0.500000      0.012195   20   0.500000      0.025000
# 16   42   0.500000      0.011905   12   0.500000      0.041667
# 17   45   0.500000      0.011111    5   0.500000      0.100000
# 18   60   0.500000      0.008333    0   0.500000           inf
# V_a=80:
#            Value    Error  ErrorRel
# _dB_dI  0.028000 0.000500  0.017857
# R_a     0.012000 0.000500  0.041667
# V_a    80.000000 3.000000  0.037500
#     I_f  Error_I_f  ErrorRel_I_f  I_a  Error_I_a  ErrorRel_I_a
# 0     0   0.500000           inf   85   0.500000      0.005882
# 1    10   0.500000      0.050000   85   0.500000      0.005882
# 2    20   0.500000      0.025000   85   0.500000      0.005882
# 3    30   0.500000      0.016667   80   0.500000      0.006250
# 4    32   0.500000      0.015625   75   0.500000      0.006667
# 5    34   0.500000      0.014706   71   0.500000      0.007042
# 6    36   0.500000      0.013889   73   0.500000      0.006849
# 7    38   0.500000      0.013158   67   0.500000      0.007463
# 8    40   0.500000      0.012500   60   0.500000      0.008333
# 9    42   0.500000      0.011905   55   0.500000      0.009091
# 10   44   0.500000      0.011364   51   0.500000      0.009804
# 11   46   0.500000      0.010870   40   0.500000      0.012500
# 12   48   0.500000      0.010417   27   0.500000      0.018519
# 13   50   0.500000      0.010000    9   0.500000      0.055556
# 14   52   0.500000      0.009615    6   0.500000      0.083333
# 15   67   0.500000      0.007463    0   0.500000           inf
# V_a=100:
#             Value    Error  ErrorRel
# _dB_dI   0.028000 0.000500  0.017857
# R_a      0.012000 0.000500  0.041667
# V_a    100.000000 0.500000  0.005000
#     I_f  Error_I_f  ErrorRel_I_f  I_a  Error_I_a  ErrorRel_I_a
# 0     0   0.500000           inf   88   0.500000      0.005682
# 1    10   0.500000      0.050000   88   0.500000      0.005682
# 2    20   0.500000      0.025000   85   0.500000      0.005882
# 3    25   0.500000      0.020000   85   0.500000      0.005882
# 4    30   0.500000      0.016667   84   0.500000      0.005952
# 5    35   0.500000      0.014286   79   0.500000      0.006329
# 6    36   0.500000      0.013889   77   0.500000      0.006494
# 7    38   0.500000      0.013158   75   0.500000      0.006667
# 8    40   0.500000      0.012500   75   0.500000      0.006667
# 9    43   0.500000      0.011628   71   0.500000      0.007042
# 10   46   0.500000      0.010870   64   0.500000      0.007812
# 11   48   0.500000      0.010417   59   0.500000      0.008475
# 12   50   0.500000      0.010000   53   0.500000      0.009434
# 13   52   0.500000      0.009615   45   0.500000      0.011111
# 14   54   0.500000      0.009259   32   0.500000      0.015625
# 15   56   0.500000      0.008929   19   0.500000      0.026316
# 16   58   0.500000      0.008621    8   0.500000      0.062500
# 17   60   0.500000      0.008333    6   0.500000      0.083333
# 18   75   0.500000      0.006667    0   0.500000           inf
# V_a=120:
#             Value    Error  ErrorRel
# _dB_dI   0.028000 0.000500  0.017857
# R_a      0.012000 0.000500  0.041667
# V_a    120.000000 0.500000  0.004167
#     I_f  Error_I_f  ErrorRel_I_f  I_a  Error_I_a  ErrorRel_I_a
# 0     0   0.500000           inf   91   0.500000      0.005495
# 1    10   0.500000      0.050000   91   0.500000      0.005495
# 2    21   0.500000      0.023810   91   0.500000      0.005495
# 3    26   0.500000      0.019231   90   0.500000      0.005556
# 4    31   0.500000      0.016129   87   0.500000      0.005747
# 5    34   0.500000      0.014706   90   0.500000      0.005556
# 6    36   0.500000      0.013889   90   0.500000      0.005556
# 7    38   0.500000      0.013158   86   0.500000      0.005814
# 8    41   0.500000      0.012195   82   0.500000      0.006098
# 9    43   0.500000      0.011628   80   0.500000      0.006250
# 10   46   0.500000      0.010870   81   0.500000      0.006173
# 11   49   0.500000      0.010204   74   0.500000      0.006757
# 12   53   0.500000      0.009434   66   0.500000      0.007576
# 13   56   0.500000      0.008929   52   0.500000      0.009615
# 14   58   0.500000      0.008621   47   0.500000      0.010638
# 15   60   0.500000      0.008333   30   0.500000      0.016667
# 16   62   0.500000      0.008065   15   0.500000      0.033333
# 17   65   0.500000      0.007692    7   0.500000      0.071429
# 18   75   0.500000      0.006667    0   0.500000           inf

# %% [markdown]
# Построим графики зависимости анодного тока $I_a$ от тока соленоида $I_f$ при каждом напряжении на аноде ($V_a$).
# Визуально определим в каждом случае критический ток через соленоид $I_{cr}$, при котором наблюдается резкое падение анодного тока.

# %%
ll.plotfit(title = "Anode current $I_a$ by solenoid current $I_f$",
           xlabel = "$I_f$",
           ylabel = "$I_a$",
           axis = [0, None, 0, None],
           x = "I_f",
           y = "I_a",
           data = [ data[e] for e in experiments ],
           columns = [ columns[e] for e in experiments ],
           label = [ e for e in experiments ])
None

# %% [markdown]
# Зафиксируем значения $I_{cr}$ для каждого напряжения на аноде.

# %%
ll.add(data["V_a=60"], ll.var(name = "I_cr", value = 35, error = 5))
ll.add(data["V_a=80"], ll.var(name = "I_cr", value = 40, error = 5))
ll.add(data["V_a=100"], ll.var(name = "I_cr", value = 45, error = 5))
ll.add(data["V_a=120"], ll.var(name = "I_cr", value = 55, error = 5))

# %% [markdown]
# Теперь будем строить зависимость критического тока $I_{cr}$ от напряжения на аноде $V_a$. Сначала рассчитаем соответствующие критическим токам напряжённости магнитного поля в соленоиде: $B_{cr} = I_{cr} * \frac{dB}{dI}$ (значение коэффициента известно заранее).

# %%
e = "global"

columns[e] = pd.DataFrame()

ll.make_column(where = columns[e], name = "V_a", varlists = data, indices = experiments)
ll.make_column(where = columns[e], name = "I_cr", varlists = data, indices = experiments)

ll.compute(name = "B_cr",
           expr = lambda I_cr, _dB_dI: I_cr * I_f_unit * _dB_dI,
           data = data[e],
           columns = columns[e])

disp(columns[e])
# Out:
#          V_a  Error_V_a  ErrorRel_V_a      I_cr  Error_I_cr  ErrorRel_I_cr  \
# 0  60.000000   0.500000      0.008333 35.000000    5.000000       0.142857
# 1  80.000000   3.000000      0.037500 40.000000    5.000000       0.125000
# 2 100.000000   0.500000      0.005000 45.000000    5.000000       0.111111
# 3 120.000000   0.500000      0.004167 55.000000    5.000000       0.090909
#
#       B_cr  Error_B_cr  ErrorRel_B_cr
# 0 0.003920    0.000564       0.143969
# 1 0.004480    0.000566       0.126269
# 2 0.005040    0.000567       0.112537
# 3 0.006160    0.000571       0.092646

# %% [markdown]
# Теперь построим график зависимости $B_{cr}^2 = f(V_a)$ и приблизим его прямой, получая коэффициент $\frac{d(B_cr{2})}{d(V_a)}$.

# %%
ll.compute(name = "B_cr_sq",
           expr = lambda B_cr: B_cr ** 2,
           data = data[e],
           columns = columns[e])

ll.plotfit(title = "Critical field strength $B_{cr}^2$ by anode voltage $V_a$",
           xlabel = "$V_a, V$",
           ylabel = "$B_{cr}^2, Tl^2$",
           model = lambda V_a, _dB_cr_sq_dV_a, _B_cr_sq_0: V_a * _dB_cr_sq_dV_a + _B_cr_sq_0,
           x = "V_a",
           y = "B_cr_sq",
           data = data[e],
           columns = columns[e])
None
# Out:
# Initial guesses for B_cr_sq = f(V_a):
#                    Value    Error  ErrorRel
# _dB_cr_sq_dV_a  0.000000 0.000000  0.367966
# _B_cr_sq_0     -0.000006 0.000011 -1.762284
#
# Final guesses for B_cr_sq = f(V_a):
#                    Value    Error  ErrorRel
# _dB_cr_sq_dV_a  0.000000 0.000000  0.184268
# _B_cr_sq_0     -0.000006 0.000005 -0.884039

# %% [markdown]
# Наконец, рассчитаем удельный заряд электрона: $\frac{e}{m} = \frac{8}{R_a^2} \frac{V_a}{B_{cr}^2}$.
#
# Он равен $\frac{e}{m} = (1.63 \pm 0.33) * 10^{11} \frac{Кл}{кг}$. Погрешность результата — $20\%$, что приемлемо, учитывая методику измерения (чтение с графика).

# %%
ll.compute(name = "_e_m",
           expr = lambda R_a, _dB_cr_sq_dV_a: 8 / (R_a**2 * _dB_cr_sq_dV_a),
           data = data[e],
           columns = columns[e])

disp(data[e].loc[["_e_m"]])
# Out:
#                    Value              Error  ErrorRel
# _e_m 163393716336.523834 33043981607.739773  0.202235
